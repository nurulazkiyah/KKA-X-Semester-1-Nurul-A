# %% [markdown]
# <a href="https://colab.research.google.com/github/nurulazkiyah/KKA-X-Semester-1-Nurul-A/blob/main/3_Aplikasi_Sederhana_Nurul_Azkiyah_X_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama : Nurul Azkiyah
#
# Kelas : X.1
#
# No. Absen : 25

# %% [markdown]
# #Aplikasi Menghitung Luas Persegi Panjang

# %%
panjang = int(input("Masukkan panjang dari persegi panjang (cm): "))
lebar = int(input("Masukkan lebar persegi panjang (cm): "))

luas = panjang*lebar

print(f"\nLuas dari persegi panjangnya adalah {luas} cm^2.")
# Out:
# Masukkan panjang dari persegi panjang (cm): 5
# Masukkan lebar persegi panjang (cm): 4
#
# Luas dari persegi panjangnya adalah 20 cm^2.

# %% [markdown]
# Nama kelompok : Kucing Manja
#
# Nama : Nurul Azkiyah
#
# Kelas : X.1
#
# No. Absen : 25

# %%
r = int(input("Masukkan jari-jari bola (cm): "))
volume = (4/3) * 22/7 * r**3

print(f"Volume bola dengan jari-jari {r} cm adalah {volume} cm³")
# Out:
# Masukkan jari-jari bola (cm): 3
# Volume bola dengan jari-jari 3 cm adalah 113.14285714285715 cm³
