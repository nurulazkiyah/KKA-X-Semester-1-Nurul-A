# %% [markdown]
# <a href="https://colab.research.google.com/github/nurulazkiyah/KKA-X-Semester-1-Nurul-A/blob/main/1_Fungsi_Print_Nurul_Azkiyah_X_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# nama : nurul azkiyah
#
# kelas : X.1
#
# absen : 25

# %% [markdown]
# #Menampilkan Teks Bebas

# %%
print("Nurul Azkiyah")
# Out:
# Nurul Azkiyah

# %% [markdown]
# #Menampilkan Nilai Variabel

# %%
nama_idola = "Hanan Attaki"
print(nama_idola)
# Out:
# Hanan Attaki

# %%
usia = 15
print(usia)
# Out:
# 15

# %% [markdown]
# latihan soal:
#
# 1.Buat variabel nama saudara & tampilkan
#
# 2.Buat variabel jumlah saudara & tampilkan

# %%
nama_saudara = "putra"
print (nama_saudara)
# Out:
# putra

# %%
jumlah_saudara = 1
print (jumlah_saudara)
# Out:
# 1

# %% [markdown]
# #Menampilkan Nilai Variabel dan String

# %%
print("Nama idola saya adalah",nama_idola,".Usianya adalah",usia,"tahun.")
# Out:
# Nama idola saya adalah Hanan Attaki .Usianya adalah 15 tahun.

# %%
print("Nama idola saya adalah "+nama_idola+".Usianya adalah "+str(usia)+" tahun.")
# Out:
# Nama idola saya adalah Hanan Attaki.Usianya adalah 15 tahun.

# %%
print(f"Nama idola saya adalah {nama_idola}.Usianya adalah {usia} tahun")
# Out:
# Nama idola saya adalah Hanan Attaki.Usianya adalah 15 tahun

# %% [markdown]
# #Escape String

# %%
print("Nama: Nurul Azkiyah")

print("Kelas: X.1")

print("No. Absen: 25")
# Out:
# Nama: Nurul Azkiyah
# Kelas: X.1
# No. Absen: 25

# %%
print("""Nama: Nurul Azkiyah

Kelas: X.1

No. Absen: 25""")
# Out:
# Nama: Nurul Azkiyah
#
# Kelas: X.1
#
# No. Absen: 25

# %%
print("""Nama\t\t: Nurul Azkiyah
Kelas\t\t: X.1
No.Absen\t: 25""")
# Out:
# Nama		: Nurul Azkiyah
# Kelas		: X.1
# No.Absen	: 25

# %%
print("Halo Nama Saya Habib Jafar")
# Out:
# Halo Nama Saya Habib Jafar

# %%
print('Halo Nama Saya Habib Jafar')
# Out:
# Halo Nama Saya Habib Jafar

# %%
print('Halo Nama Saya Habib Ja\'far')
# Out:
# Halo Nama Saya Habib Ja'far

# %%
print ("Halo Nama Saya Habib Ja'far")
# Out:
# Halo Nama Saya Habib Ja'far

# %%
print("Bu Shinta berkata,\"Tolong fokus ke TV sejenak.\"")
# Out:
# Bu Shinta berkata,"Tolong fokus ke TV sejenak."

# %%
print('Bu Shinta berkata,"Tolong fokus ke TV sejenak.')
# Out:
# Bu Shinta berkata,"Tolong fokus ke TV sejenak.

# %%
print("Silakan simpan file tugas KKA di folder Local disk D:\\MAN Demak\\KKA\\Tugas")
# Out:
# Silakan simpan file tugas KKA di folder Local disk D:\MAN Demak\KKA\Tugas

# %%
print('Bu Shinta berkata, "Berikut adalah daftar piket harian kelas X.2 yang disimpan di file D:\\MAN Demak\\Jadwal Piket."\n\nSenin\tSelasa\tRabu\nJielo\tHasbi\tNaufal\nAzam\tA\'inun\tNurul\t')
# Out:
# Bu Shinta berkata, "Berikut adalah daftar piket harian kelas X.2 yang disimpan di file D:\MAN Demak\Jadwal Piket."
#
# Senin	Selasa	Rabu
# Jielo	Hasbi	Naufal
# Azam	A'inun	Nurul

# %% [markdown]
# #Parameter Fungsi Print

# %%
nama_siswa_1="Dias"
nama_siswa_2="Disa"

print(nama_siswa_1)
print(nama_siswa_2)
# Out:
# Dias
# Disa

# %%
nama_siswa_1="Dias"
nama_siswa_2="Disa"

print(nama_siswa_1, end=" ")
print(nama_siswa_2)
# Out:
# Dias Disa

# %%
print(nama_siswa_1, nama_siswa_2)
# Out:
# Dias Disa

# %%
print(nama_siswa_1, nama_siswa_2, sep="-")
# Out:
# Dias-Disa

# %%
nama_siswa_3 = "Kinan"
nama_siswa_4 = "Azka"
nama_siswa_5 = "Naufal"
nama_siswa_6 = "Ridho"

print(nama_siswa_6, nama_siswa_3, nama_siswa_5, nama_siswa_4, nama_siswa_4, sep="/")
# Out:
# Ridho/Kinan/Naufal/Azka/Azka

# %%
print(nama_siswa_4, end="*")
print(nama_siswa_4, end="*")
print(nama_siswa_5, end="*")
print(nama_siswa_3, end="*")
print(nama_siswa_6,)
# Out:
# Azka*Azka*Naufal*Kinan*Ridho
